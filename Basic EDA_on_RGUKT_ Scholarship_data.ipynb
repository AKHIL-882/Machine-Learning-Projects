# %% [markdown]
# <a href="https://colab.research.google.com/github/AKHIL-882/Machine-Learning-Projects/blob/main/Basic%20EDA_on_RGUKT_%20Scholarship_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.1 Importing the Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1.2 Reading the dataset**

# %%
dataset = pd.read_csv("students.csv")
dataset.head()
# Out:
#   student id              student full name  ... Unnamed: 9 Unnamed: 10
# 0   RS200620                 Karri Gayathri  ...        NaN         NaN
# 1    S190523     Kesireddy. Madhavi Ushasri  ...        NaN         NaN
# 2   RS200424  GOLAKOTI Y L GANAPATHI RAYULU  ...        NaN         NaN
# 3   Rs200905                     Dukka Nani  ...        NaN         NaN
# 4    S190367                Jhansi kurakula  ...        NaN         NaN
#
# [5 rows x 11 columns]

# %% [markdown]
# **1.3 Renaming the columns**

# %%
dataset= dataset.rename(columns = {'student id': 'student_id', 'student full name': 'full_name', 'year': 'year','reason for not tallying (if any)': 'reason' }, inplace = False)
dataset

# %% [markdown]
# **1.4 Slicing the dataframe**

# %%
dataset_new = dataset_new[['student_id','full_name','year','reason']]
dataset_new.head()
# Out:
#   student_id  ...                               reason
# 0   RS200620  ...       need transaction id and utr no
# 1    S190523  ...       need transaction id and utr no
# 2   RS200424  ...  [id number wrong upload once again]
# 3   Rs200905  ...       need transaction id and utr no
# 4    S190367  ...       need transaction id and utr no
#
# [5 rows x 4 columns]

# %% [markdown]
# **1.5 Entire information of Songs dataset**

# %%
print("-------------------------------------------------------\nChecking Null values\n-------------------------------------------------------")
print(" " ,dataset_new.isnull().sum())
print("-------------------------------------------------------\nShape of the dataset\n-------------------------------------------------------")
print(" ",dataset_new.shape)
print("-------------------------------------------------------\nInformation of dataset\n-------------------------------------------------------")
print("", dataset_new.info())
print("-------------------------------------------------------\nDescription of the dataset\n-------------------------------------------------------")
print("",dataset_new.describe())
print("-------------------------------------------------------\nChecking duplication records\n-------------------------------------------------------")
print(sum(dataset_new.duplicated()))
print("-------------------------------------------------------\nDroping the NaN values\n-------------------------------------------------------")

print(dataset_new.dropna(axis='columns'))
print(dataset_new.dropna(how='all'))
print("-------------------------------------------------------\nChecking for Null\n-------------------------------------------------------")
print(dataset_new.isnull().sum())
print("-------------------------------------------------------\nRemoving the Null values\n-------------------------------------------------------")
dataset_new = dataset_new.dropna()
print(dataset_new.count())
dataset_new.head()

print("-------------------------------------------------------\nUnique Values\n-------------------------------------------------------")
dataset_new = dataset_new.nunique()
dataset_new
# Out:
# -------------------------------------------------------
# Checking Null values
# -------------------------------------------------------
#   student_id    615
# full_name     615
# year          616
# reason        615
# dtype: int64
# -------------------------------------------------------
# Shape of the dataset
# -------------------------------------------------------
#   (982, 4)
# -------------------------------------------------------
# Information of dataset
# -------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  367 non-null    object
#  1   full_name   367 non-null    object
#  2   year        366 non-null    object
#  3   reason      367 non-null    object
# dtypes: object(4)
# memory usage: 30.8+ KB
#  None
# -------------------------------------------------------
# ...

# %% [markdown]
# **1.6 Barplot to find number of students based on year**

# %%
dataset['year'].value_counts().plot(kind = 'bar')

# %% [markdown]
# **Observation: PUC-1 studenta have commited miskates while uploading the recipt**

# %% [markdown]
# **1.7 Most visible reasons for the student name in the list**

# %%
dataset['reason'].value_counts().plot(kind = 'bar')

# %% [markdown]
# **Observation: The main reason is " need transaction id and utr no"**

# %% [markdown]
# **1.8 Counting the values in each column**

# %%
l = ['year','reason','student_id','full_name']
for col in l:
    print("***"*40)
    print(col)
    print(dataset[col].value_counts())
    print("***"* 40)
    print("\n")
# Out:
# ************************************************************************************************************************
# year
# PUC-1    110
# PUC-2     81
# E1        78
# E2        57
# E3        40
# Name: year, dtype: int64
# ************************************************************************************************************************
#
#
# ************************************************************************************************************************
# reason
# need transaction id and utr no                                                    272
# need student id no on slip                                                         45
# need transaction id and utr no and account number                                   4
# paid only 10000 (pay remaining vidya deevena)                                       4
# upload proof                                                                        4
# ...

# %% [markdown]
# **Observation: We can find that some of the ID's are repeated with another reasons**

# %% [markdown]
# **1.9 Counterplot to demostrate year of students commited mistakes**

# %%
sns.countplot(dataset['year'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Observaton: The number of students from each brach
# PUC-1   -  110  ----
# PUC-2   -   81  ----
# E1      -   78  ----
# E2      -   57  ----
# E3       -  40   ----
# respectively**

# %% [markdown]
# **2.0 Counterplot for year and reason**

# %%
fig,ax = plt.subplots(figsize = (5,10))
sns.countplot(y = 'reason', data = dataset, hue = 'year')
plt.title('Year vs Reason')
plt.xlabel('Reason')
plt.ylabel('Year')
# Out:
# Text(0, 0.5, 'Year')

# %% [markdown]
# **Developer : Duggirala Akhil**
#
# **ID.N0: S160882**
#
# **Course** : B.Tech-Computer Science and Engineering - III year
#
# **College** : Rajiv Gandhi University of Knowledge Technologies - IIIT Srikakulam
